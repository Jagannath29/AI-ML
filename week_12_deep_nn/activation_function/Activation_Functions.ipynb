# %% [markdown]
# # Activation Functions

# %% [markdown]
# ## Pre-requisites
# To start this lession with activation function **all students must be aware** of the following concepts:
# * Linearly Seperable and Inseparable functions
# * Forward Propagation

# %% [markdown]
# ## Learning Objectives
# By the end of this lesson, **all learners** will be able to:
# <!-- [ C=Condition + A=Actor + B=Behaviour + D=Degree ]  -->
#
# <!-- [Remember] -->
# * Recall linearly separable and inseparable data structures,  how and why non linearity is introduced to make classifications
# <!-- [Understand] -->
# * Explain the different types of activation functions along with their domain, range and derivative
# <!-- [Apply] -->
# * Implement the mathematical formulation to basic modular functions using numpy and visualise for sigmoid, tanh and also variations of ReLU
# <!-- [Analyze] -->
# * Breakdown the advantages, disadvantages and the use case scenarios of different activation functions
# <!-- [Evaluate] -->
# * Critique on use of specific activation function on specific problem with proper reasoning
# <!-- [Create]  -->

# %% [markdown]
# ## Introduction

# %% [markdown]
# ### Recall Linearly Separable and Inseparable Functions
# **Why do we need activation functions?**
# In the previous section in perceptron, we used the term sigmoid function which actually is an activation used to enable perceptron to learn function which is other than simpler linear function.
#
# <!-- Image Template -->
#
# <center>
# <figure>
#
#
# <p><img src="data:image/png;base64,..."  ></p>
# <figcaption align="center">Figure 1: Perceptron with Sigmoid Activation </figcaption>
# </figure>
# </center>
#
# Just before **feeding the output of neuron to the sigmoid function**, we are learning the linear function $z=x_1w_1+x_2w_2+x_3w_3$. If we hadn't used sigmoid, we won't be able to learn non-linear mapping between input and output.
#
# The data in the real life are generally linearly inseparable, though some are linearly separable.
#
#
#
#  <center>
# <figure>
#
#
# <p><img src="data:image/png;base64,..."  ></p>
# <figcaption align="center">Figure 2: Linearly Separable Vs In-Separable Data </figcaption>
# </figure>
# </center>
#
# As shown in the above figure, the data in the left part is linearly separable, so it's okay not to use the the activation function. However, if the data is linearly inseparable as in the right section of the above figure we will need the complex function other than a straight line. So **by using activation function, we can introduce non-linearity as most of the real data are linearly inseparable**. Otherwise, we will end up just learning linear function.
#
# <center>
# <figure>
#
#
# <p><img src="data:image/png;base64,..."  ></p>
# <figcaption align="center">Figure 3: Linearly In-Separable Classes Separated by Linear Decision Boundary (1) Linearly In-Separable Classes Separated by Non-Linear Decision Boundary (2) </figcaption>
# </figure>
# </center>
#
# The above figure shows how we can make our neural network more powerful and enable it to learn complex and complicated data and **represent a non-linear complex arbitrary mapping between inputs and outputs using activations.** So we have understood why the use of activation function is crucial in a neural network.

# %% [markdown]
# ###  Activation Functions
#
# <!-- What is activation function?
# and
# Why cant any functon be an activation function? -->
# So briefly until this portion of the lecture, we have come to understand why we need an activation function. In order to create a nonlinear decision boundary, activation function plays a vital role.
# Now, let's discuss what an activation function really is.
#
# The input to an activation function is the weighted sum (between the weights and inputs to that particular neuron), also called as $Z$ value. Now this value of $Z$ can vary from $[-\infty$  to $+ \infty] $ which is a large number of values to work on. **Inspired from the concept of neurons firing only after the stimulus reaching a certain threshold,** the activation function here, decides **whether the neuron should fire or not based on the values of $Z$**. This concept works fine when we are talking about classification based on two classes. (_For a linearly Separable data_)
#
# Algorithmically,
#
# $ If(Activation Function Output >= Threshold Value)$
# $\space\space\space\space\space$Fire/Activate the Neuron
# else
# $\space\space\space\space\space$Deactivate the Neuron
#
#
# <center>
# <figure>
#
#
# <p><img src="data:image/png;base64,..." height="373" width="744"></p>
# <figcaption align="center">Figure 4: 2 layer neural network with activation function $f(x)$ </figcaption>
# </figure>
# </center>
#
#
# **Problem formulation**
# What if we have a multiclass classification problem like classification of  fruits in a basket containing more than 2 classes of fruits, say 4?
# Our **step activated or Binary (1/0) or (Yes/No) or digital activation** neuron gets activated for more than one class of fruits making it impossible for us to distinguish which fruit. For example: It might get activated for apple along with pear and orange but deactivated for banana and mango at the same time.
# **So what we need is an activation function that outputs say, 40% of Class 1, 30% of class 2 and so on rather than 100% of Class 1 and 2 and 3**. This concept is called as **analog activation** (for example giving a probability from 0 to 1, analog values).
#
# Similarly, a neural network works on the concept of learning parameters based on optimization algorithms like Gradient Descent. considering a **linear activation function of form  $y=cx$, the derivative of this function is a constant $c$ which doesnt propagate errors or update the learning parameters.**
#
# Hence, **an ideal activation function will output analog activations and easily propagate errors** i.e. is differential with respect to the learning parameters.
#
# Some of most widely activation functions are illustrated below:

# %% [markdown]
# ## **Types of Activation Functions**
# Let's discuss some mostly used activation functions:

# %% [markdown]
# ### **Sigmoid Activation Function**
# The input-output mapping function in sigmoid activation is $\phi(z)=\frac{1}{1+e^{-z}}$
#
# This function mostly **appears in the output layer of DL architecture and is used for probability based output and has been applied successfully in binary classification problem and logistic regression.**
#
# Sigmoid is a non-linear activation function used mostly in feed forward neural networks. It is a bounded differentiable real funciton defined for real input values with positive derivatives everywhere and some degree of smoothness.
# The figure below shows the plot of mapping between input and output:
#
# <center>
# <figure>
#
#
# <p><img src="data:image/png;base64,..." height="311" width="471"></p>
# <figcaption align="center">Figure 5: Sigmoid Function Plot </figcaption>
# </figure>
# </center>
#
# **The above curve shows that any input will be scaled to a value between [0 to 1] for any input ranging from $- \infty \space to + \infty $**
# $$ 0< \phi(z) < 1$$
#
# **Domain** :$- \infty \space to + \infty $
# **Range** :[$0 \space to 1$]
#
# For example,
#
# When x=2, $\rightarrow f(z)=\frac{1}{1+e^{-2}}=0.8808$
#
# When x=-1,$\rightarrow f(z)=\frac{1}{1+e^1}=0.26894$
#
# Similarly, The derivative of sigmoid activation function, $y$ with respect to input values $z$ is computed as:
#
# $$
# \begin{align*}
# y &= \frac{1}{1-e^{-z}} \\
# \frac{dy}{dz} &= \frac{d}{dz} \left(\frac{1}{1-e^{-z}}\right) \\
#  &= -\frac{1}{(1-e^{-z})^2} \frac{d}{dz} (1 - e^{-z}) \\
#  &= -\frac{1}{(1+e^{-z})^2}(-e^{-z}) \\
#  &= \frac{e^{-z}}{(1+e^{-z})^2} \\
#  &= \frac{1 + e^{-z} - 1}{(1+e^{-z})^2} \\
#  &= \frac{1}{1 + e^{-z}} \left(\frac{1 + e^{-z} - 1}{1+e^{-z}}\right) \\
#  &= \frac{1}{1+e^{-z}}\left(1-\frac{1}{1+e^{-z}}\right)=y(1-y)\\
# Thus, \frac{dy}{dz} &=y(1-y)
# \end{align*}
# $$
#
#
# The plot of it's derivative is:
#
# <center>
# <figure>
#
#
# <p><img src="data:image/png;base64,..."  ></p>
# <figcaption align="center">Figure 6: Derivative of Sigmoid Function </figcaption>
# </figure>
# </center>
#
#
# The derivative equation shows that it's very easy to compute the derivative of the sigmoid function if we've already calculated the sigmoid function itself. When backpropagating errors in a neural network through a layer of nodes with a sigmoid activation function,
# σ(x) has already been computed during the forward pass. As we can see, the derivative curve is symmetric, bell shaped and positive everywhere.
#
# **Advantages and Disadvantages**:
# The advantages of using sigmoid function as activation function are:
# * It introduces **non-linearity** which enables the network to learn a complex mapping between input and output.
# * It **prevents blowing of the activation** as it scales any input to value between 0 and 1.
#
# where as, it suffers **sharp damping of gradient during the backpropagation** from deep hidden layers to the input layers, gradient saturation, and slow convergence i.e.
#
# * Gradient **vanishes** when the input is large or small.
# When x is large, then $y \rightarrow 1,$ implies $y^{'} \rightarrow 1(1-1)=0 $,
# as shown in above graph of sigmoid and it's derivative.
#
#   Beside this, the range of it's derivative is $(0, 1/4]$. This means that  the value while **backprogating will be very small or at maximum** it can be  $1/4$ and hence, it will result in **vanishing gradient problem if backpropagated throuh deep neural network **and hence, the neural network will learn nothing.
# * Optimization of network gets harder because the output isn't **zero centered(it is centered at 0.5).**

# %% [markdown]
# ### **Softmax Activation Function**
#  Softmax activation function is the generalization of the sigmoid function which was used to represent a probability distribution over a binary variable. Softmax activation function is used in the output layer of neural network model that predict a multinomial probability distribution. It is used for multiclass classification problem.
#
# Mathematically softmax function can be written as,
# $$
# \sigma(z)_i = \frac{e^{z_i}}{\Sigma_{j=1}^{K} e^{z_j}}
# $$
# Here, we apply a exponential function to each element $z_i$ of the input vector ${\displaystyle \mathbf {z} }$ and normalize these values by dividing by the sum of all these exponentials. The sum of the elements of the output vector ${\displaystyle \sigma (\mathbf {z} )}$ is 1 because of the normalization.

# %%
# example of a function for calculating softmax for a list of numbers
from numpy import exp

# calculate the softmax of a vector
def softmax(vector):
	e = exp(vector)
	return e / e.sum()

# define data
data = [1, 3, 2]
# convert list of numbers to a list of probabilities
result = softmax(data)
# report the probabilities
print(result)
import numpy as np
print(np.array([1,3,2])/np.array([1,3,2]).sum())
# report the sum of the probabilities
print(sum(result))
# Out:
# [0.09003057 0.66524096 0.24472847]
# [0.16666667 0.5        0.33333333]
# 1.0

# %% [markdown]
# ### **Hyperbolic Tan Activation Function**
#
#
#
# This activation function is very similar to the sigmoid activation function **except that the output is zero centered. The output is zero centered as the mapping scales the input value between -1 and 1.**
#
# The hyperbolic tan activation function is given as:
# $$ f(x)=\frac{1-e^{-2x}}{1+e^{-2x}}$$
#
# **Domain**: $- \infty \space to + \infty $
# **Range**: [$-1 \space to 1$]
#
# <center>
# <figure>
#
#
# <p><img src="data:image/png;base64,..." height="313" width="506"></p>
# <figcaption align="center">Figure 7: Tanh Function Plot </figcaption>
# </figure>
# </center>
#
# Hyperbolic tan activation is mostly used in **Recurrent Neural Network for natural language processing.**
#
# Similarly, the derivative of tanh with respect to x (input values) is given by:
#
# According to the quotient rule:
#
# <center>
# $\dfrac{d(f/g)}{dx}=\dfrac{gf^\prime-fg^\prime}{g^2}$
#
# $set f= \sinh, g=\cosh $  to get, $\space\space\space$
# $\dfrac{d\tanh}{dx}=\dfrac{\cosh\cdot\sinh^\prime-\sinh\cdot\cosh^\prime}{\cosh^2}$
# </center>
# Now,
# <center>
# $\sinh^\prime=\dfrac{1}{2}(e^x+e^{-x})=\cosh\\
# \cosh^\prime=\dfrac{1}{2}(e^x-e^{-x})=\sinh$
# </center>
# Thus,
#
# <center>$\dfrac{d\tanh}{dx}=\dfrac{\cosh^2-\sinh^2}{\cosh^2}=1-\left(\dfrac{\sinh}{\cosh}\right)^2=1-\tanh^2$</center>
#
# Now,
#
# <center>$\dfrac{1}{\cosh^2}=1-\tanh^2$</center>
#
# Proof:
# <center>$1-\dfrac{\sinh^2 x}{\cosh^2 x}= \dfrac{\cosh^2 x-\sinh^2 x}{\cosh^2 x}$
#
# and
#
# $\dfrac{1}{\cosh^2 x} = {\operatorname{sech}^2 x}$
# </center>
#
# Thus,
#
# <center>$\boxed{\dfrac{d\tanh}{dx}=1-\tanh^2=\dfrac{1}{\cosh^2 x}}$</center>
#
# \
# **Advantages and Disadvantages**
#
# The tanh function couldn't solve the vanishing gradient problem suffered by sigmoid function. The main advantage is that it produce **zero centered output** thereby aiding the back propagation process. Optimization of the network using hyperbolic tan activation is easier.

# %%
# example of a function for calculating softmax for a list of numbers
from numpy import exp

# calculate the softmax of a vector
def tanh(vector):
	e = 1-exp(-2*vector)/1+exp(-2*vector)
	return e

# define data
data = [1, 3, 2]
# convert list of numbers to a list of probabilities
result = tanh(data)
# report the probabilities
print(result)
import numpy as np
print(np.array([1,3,2])/np.array([1,3,2]).sum())
# report the sum of the probabilities
print(sum(result))
# Out:
# []
# [0.16666667 0.5        0.33333333]
# 0

# %% [markdown]
# ###  **Rectified Linear Unit (ReLU)**
# ReLU is an activation function famous for CNNs (Convolutional Neural Network) and most commonly used as activation in hidden layers in a neural network.
#
# ReLU is defined as:
# $$R(z)=max(0,z)$$
#
# <center>
# <figure>
#
#
# <p><img src="data:image/png;base64,..." height="384" width="473"></p>
# <figcaption align="center">Figure 8: ReLU Function Plot </figcaption>
# </figure>
# </center>
#
#
# The ReLU function acts as a **threshold to each input element where values less than zero are set to zero**. ReLU function rectifies the values of input less than zero thereby forcing them to zero and **eliminating the vanishing gradient problem.**
#
# The derivative of ReLU activation function is:
#
# \begin{equation}
# R'(z)=
#     \begin{cases}
#       1, & \text{if}\ z>0 \\
#       0, & \text{otherwise}
#     \end{cases}
# \end{equation}
#
#
# Here, The function is mostly differential but the value of the derivative of ReLU function is **undefined at** $z=0$. One way to deal with this problem while backpropagating is to assign an arbitrary value for derivative at $z=0$. Some common values are 0, 0.5 and 1.
#
# **Advantages and Disadvantages**
# One major advantage of using ReLU is the **reduced likelihood of the gradient to vanish. In the region, $z>0$ the gradient has a constant value**. The constant gradient of ReLUs results in faster learning. Moreover, ReLU is computationally more efficient to compute than Sigmoid because Relu just needs to pick $max(0,z)$ and not perform expensive exponential operations as in Sigmoids.
# Also, **it introduces sparsity in the hidden units** as it squishes the value between zero to maximum.
#
# However, ReLU has some problem too, i.e, it **tends to blow up activation (there is no mechanism to limit/rescale the output of the neuron, as "z" itself is the output)**. Relu function easily **overfits** compared to the sigmoid function. Moreover, there is another problem called **"Dying ReLU problem"** - if too many activations get below zero then most of the neurons in the network with ReLU will output zero, in other words, die and thereby prohibiting learning.
#
# \
#
# ####  **Variations of ReLU**
# #####  **Leaky ReLU**
# Leaky ReLU is the specialized version of Randomised ReLU. When the value of parameter $\alpha$ is 0.01, then it becomes LReLU.
#
# Mathematically, for Leaky ReLU,
#
# $$ R(z)=
# \begin{array}{cc}
#   \{ &
#     \begin{array}{cc}
#       \alpha z & z\lt 0 \\
#       z & z\geq 0
#     \end{array}
#     \}&
# \end{array}
# $$
#
#
# #####  **Sin ReLU (SReLU)**
# Sin ReLU is defined as
#
# $$ R(z)=
# \begin{array}{cc}
#   \{ &
#     \begin{array}{cc}
#       z & z\gt 0 \\
#       \varepsilon(sin(z)-cos(z)) & z\leq 0
#     \end{array}
#     \}&
# \end{array}
# $$
# where, $\varepsilon$ controls the wave amplitude.
#
# The following plot shows SinReLU activation:
#
# <center>
# <figure>
#
#
# <p><img src="data:image/png;base64,..." height="353" width="551"></p>
# <figcaption align="center">Figure 9: SinReLU Function Plot </figcaption>
# </figure>
# </center>
#
#
# #####  **Randomised ReLU (RReLU)**
# Randomized ReLU is a **dynamic variant of leaky ReLU** where a random number sampled from uniform distrubution is used to train the network.
# For RReLU, we have
# $$ R(z)=
# \begin{array}{cc}
#   \{ &
#     \begin{array}{cc}
#       \alpha z & z\lt 0 \\
#       z & z\geq 0
#     \end{array}
# \end{array}
# $$
#
# Where,
# $\alpha$ is a parameter, representing slope.
#
# When $\alpha$=0.01, we have LReLU. However, when $\alpha \ne 0.01,$ then we obtain randomized ReLU.

# %% [markdown]
# ##  Implementation and Visualisation
#
# ###  Sigmoid Function and Hyperbolic Tah

# %%
#Importing Numpy Library
import numpy as np
#Generating 200 values of x in between [-10,10]
x = np.linspace(-10, 10, 200)
print(x)
print(x.shape) # Validating the number of vlaues of x
# Out:
# [-10.          -9.89949749  -9.79899497  -9.69849246  -9.59798995
#   -9.49748744  -9.39698492  -9.29648241  -9.1959799   -9.09547739
#   -8.99497487  -8.89447236  -8.79396985  -8.69346734  -8.59296482
#   -8.49246231  -8.3919598   -8.29145729  -8.19095477  -8.09045226
#   -7.98994975  -7.88944724  -7.78894472  -7.68844221  -7.5879397
#   -7.48743719  -7.38693467  -7.28643216  -7.18592965  -7.08542714
#   -6.98492462  -6.88442211  -6.7839196   -6.68341709  -6.58291457
#   -6.48241206  -6.38190955  -6.28140704  -6.18090452  -6.08040201
#   -5.9798995   -5.87939698  -5.77889447  -5.67839196  -5.57788945
#   -5.47738693  -5.37688442  -5.27638191  -5.1758794   -5.07537688
#   -4.97487437  -4.87437186  -4.77386935  -4.67336683  -4.57286432
#   -4.47236181  -4.3718593   -4.27135678  -4.17085427  -4.07035176
#   -3.96984925  -3.86934673  -3.76884422  -3.66834171  -3.5678392
#   -3.46733668  -3.36683417  -3.26633166  -3.16582915  -3.06532663
# ...

# %%
#Defining Sigmoid Function
def sigmoid(x):
    return [(1/(1+np.exp(-i))) for i in x]

#Defining Hyperbolic Tan Function
def tanh(x):
    return [((1-np.exp(-2*i))/(1+np.exp(-2*i))) for i in x]

# %%
#Passing values of x to sigmoid function
y_sig=sigmoid(x)

#Passing values of x to tanh function
y_tanh=tanh(x)

# %%
#Importing Matplotlib Library
import matplotlib.pyplot as plt
# %matplotlib inline

#Scatter Plot for Sigmoid Function
plt.scatter(x,y_sig, c='b', label = 'Sigmoid')
#Scatter Plot for Tanh Function
plt.scatter(x,y_tanh, c="r", label = 'tanh')
plt.legend(loc='lower right')
#Labels
plt.title('Scatter plot for Sigmoid and Tanh Function')
plt.xlabel('input to activations(x)')
plt.ylabel('output values(y)')
plt.show()

# %% [markdown]
# **In above plot between tanh and sigmoid, we can observe that the output for tanh is zero-centerd while sigmoid is not.**

# %% [markdown]
# ###  Variants of ReLU

# %%
#Defining Function for ReLU and its variants
def Relu(x):
    return [ (lambda i: i if (i>0) else 0)(i) for i in x]

def leaky_relu(x):
    return [ (lambda i: i if (i>=0) else 0.1*i)(i) for i in x]

def sin_relu(x):
    epsilon = 0.1
    return [ (lambda i: i if (i>0) else epsilon*(np.sin(i)-np.cos(i)))(i) for i in x]

def rand_relu(x):
    # np.random.seed(1)
    alpha = np.random.rand(1)
    return [ (lambda i: i if (i>0) else alpha* i)(i) for i in x]

# %%
y_relu = Relu(x)
y_lrelu = leaky_relu(x)
y_srelu = sin_relu(x)
y_rrelu = rand_relu(x)

#ReLU=RED
plt.scatter(x, y_relu, c='r',label='ReLU')
#Leaky ReLU=GREEN
plt.scatter(x, y_lrelu, c='g', label = 'Leaky ReLU')
#SReLU=Blue
plt.scatter(x, y_srelu, c='b', label = 'SReLU')
#RReLU=Yellow
plt.scatter(x, y_rrelu, c='y', label = 'RReLU')
plt.legend(loc='lower right')

#Visualizing in a combine plot
plt.title('Scatter plot for ReLU, Leaky ReLU, SReLU and RReLU')
plt.xlabel('input to activations(x)')
plt.ylabel('output values(y)')
plt.show()

# %%
#Visualizations in multiple subplots
plt.figure(figsize=(10,10))
plt.subplot(321)
plt.tight_layout()
plt.scatter(x, y_relu, c='r')
plt.title('RELU')
plt.xlabel('x')
plt.ylabel('y')

plt.subplot(322)
plt.tight_layout()
plt.scatter(x, y_lrelu, c='g')
plt.title('Leaky Relu')
plt.xlabel('x')
plt.ylabel('y')

plt.subplot(323)
plt.tight_layout()
plt.scatter(x, y_srelu, c='b')
plt.title('Sin Relu')
plt.xlabel('x')
plt.ylabel('y')

plt.subplot(324)
plt.tight_layout()
plt.scatter(x, y_rrelu, c='y')
plt.title("Randomized Relu")
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# ##  Use case of different activation functions
#
# **Sigmoid function**: This activation function is used when we are doing Binary Classification modeling.
#
# **Hyperbolic tan Function:**  Tanh function is mostly used in recurrent neural network for natural language processing and speech recognition task.
#
# **ReLU Function**: This activation function eliminates the vanishing gradient problem. So, mostly used in the hidden units of deep neural network. Also, used in the output layer of the network which are used for object classification and speech recogition application.
#
# <!--**Zero-centered activation:** Zero activation function make sure that mean activation value is around zero.This is important because we know that model operations converges faster on normalized data.-->

# %% [markdown]
# ## Key Takeaways
# * In order to create a nonlinear decision boundary, activation function plays a vital role. Without activation functions, we can only learn linear decision boundaries.
# * Sigmoid activation function is used when we are doing binary classification problems as it outputs a number between 0 and 1.
# *  The output of tanh activation function is zero centered as the output is mapped between -1 and 1 which is its main advantage and aids the back propagation process. Optimization of the network using hyperbolic tan activation is easier.
# * ReLU activation function eliminates the vanishing gradient problem. So, it is mostly used in the hidden units of deep neural network.

# %% [markdown]
# ## Resources
# * [Kapur, R. (2017, April 11). Rohan #4: The vanishing gradient problem. Retrieved July 27, 2020, from https://ayearofai.com/rohan-4-the-vanishing-gradient-problem-ec68f76ffb9b?gi=91e9112575e](https://ayearofai.com/rohan-4-the-vanishing-gradient-problem-ec68f76ffb9b)
#
# * [Nwankpa, C., Ijomah, W., Gachagan, A., & Marshall, S. (2018). Activation functions: Comparison of trends in practice and research for deep learning. arXiv preprint arXiv:1811.03378.](https://arxiv.org/pdf/1811.03378.pdf)

# %% [markdown]
# <!-- Image Template -->
# <!--
# <center>
# <figure>
# <img src="" alt="" >
# <figcaption align="center">Figure </figcaption>
# </figure>
# </center>  -->
