# %% [markdown]
# ## Prerequisites
#
# Before beginning this chapter, you should be familiar with,
#
# - basic set and logical operations
# - basic idea of image and pixels
# - basics idea of vectors and matrics

# %% [markdown]
# ## Learning Objectives
#
# After this chapter, you will be able to:
#
#   - define mathematical morphology
#   - explain general idea on elements used in morphology
#   - discuss operations important in morphological processing

# %% [markdown]
# ## Detailed outlines
#
# In this chapter, we will walkthrough five major topics as follows,
#
# - Introduction
#
# - Morphological Operators
#
# - Structuring Elements
#
# - Morphological Operations
#
# - Applications

# %% [markdown]
# ## Introduction

# %% [markdown]
# Before beginning to define the morphological image processing, its usage, let's discuss the term `Morphology.` Morphology in image processing is a tool for extracting image features useful in the representation and description of region shapes, such as boundaries, skeletons, and the convex hull.

# %% [markdown]
# You can define `Morphological image processing` as the various non-linear image processing operations that deal with the shape of the image's features. Most of the morphological analysis techniques operate on the binary images. You also use it in case of the grayscale images .

# %% [markdown]
# You use morphological processing for various tasks like boundaries extraction, skeletons, thinning, pruning, morphological filtering, convex hull, reduce noise, brighten the image, etc.
#
# It usually takes an image and a structuring element as input and combines them using the morphological operators. Now, let's discuss the morphological operators and later on have a discussion on the structuring element.

# %% [markdown]
# **NOTE:**
#
# - Binary images consist of two values 0's and 1's where 1 (white) represents foreground pixel, and 0 represents the background pixel.
#
# - You obtain binary images from grayscale images by using methods like thresholding, segmentation.

# %% [markdown]
# ## Morphological Operators

# %% [markdown]
# Morphological operators are mainly based on the mathematical concepts from set-theory. These operators are useful for the analysis of binary images.

# %% [markdown]
# Morphological operators includes the set theory concept like Subset($A\subseteq B$), Union($A\cup B$), Intersection($A\cap B$), Complement($A^\complement$), difference($A-B$), reflection, and translation. Most of you might be familiar with the Union, Subset, Intersection, Complement,  and difference, so here, we are not discussing these operators. Later on, you see a brief explanation of reflection and translation.
#
# <div align="center">
# <figure>
# <!-- <img src="https://drive.google.com/uc?id=1C80DqSeYwEOJ58zFGLwVxGtBclNid8tt" > -->
# <img src="https://i.postimg.cc/0j7TSpFy/image.png"/>
# <figcaption>Figure 1. Morphological operations with logical operations
# </figcaption>
# </figure>
# </div>

# %% [markdown]
# Morphological operators also include the logical operators like AND, OR, NOT, XOR, NAND for performing the logical operations on a pixel by pixel basis between corresponding pixels(bitwise operations). Here, you know that logical operations are just a private case for binary set operations such as Intersection(AND), Union(OR), Complement(NOT). The above figure shows some basic morphological operations with logical operators like NOT, AND, OR, XOR. In the figure, A and B represents two binary images and we can see how different operations change the output images.

# %% [markdown]
# **Reflection and Translation**
#
# Any morphological operations extensively use either reflection or translation or both.

# %% [markdown]
# ***Reflection***:
#
# For a structuring element $B$, reflecting about origin means simply rotation of B by $180^\circ$ about its origin. This means, the new reflected element $\hat{B}$ represents a set of pixels within B, with $(x,y)$ replaced by $(-x, -y)$. Mathematically,
# $$
#     \hat{B} = \{ w | w = -b,\ for\ b \in B\}
# $$
# Carefully look at this figure, if you aren't clear.
#
# <div align="center">
# <figure>
# <!-- <img src="https://drive.google.com/uc?id=1HGvmLtqsjjFnpJF1vvUhcG8g-esU3fhJ" width=400> -->
# <img src="https://i.postimg.cc/3J54HYZX/image.png">
# <figcaption>Figure 2. Figure showing reflection operation
# </figcaption>
# </figure>
# </div>
#
#
# In the above figure, you see that the left and right portions structuring elements are rotation at an angle $180^\circ$ about its origin. It is so because of the reflection performed on it about the origin(represented by the dot in the figure).

# %% [markdown]
# **NOTE:**
#
# * `Gray portion` in the above figure represents `background pixel`, and `white portion` represents the `foreground pixels`.
#
# * `dot(.)` in the above figure represents the origin of the structural element.

# %% [markdown]
# ***Translation:***
#
#   For any structuring element $B$, translating it gives element $(B)_z$. The coordinates of the pixels is set $(B)_z$ will be equal to $(x + z_1, y + z_2)$. Mathematically we can represent as
# $$
#     (B)_z = \{c|c = b + z,\ for\ b \in B\}
# $$
#
#   As you translate the sliding element over the image, the operation happens only in the area where there is a structuring element and the area structuring element overlaps with.
#
# <div align="center">
# <figure>
# <!-- <img src="https://drive.google.com/uc?id=1TYxf7fB0QKQlfvE4AN9SS5iFRf104xk2" height=200 > -->
# <img src=" https://i.postimg.cc/4dRkxL2S/image.png"/>
# <figcaption>Figure 2. Translation of structuring element
# </figcaption>
# </figure>
# </div>

# %% [markdown]
# Here, you learned a new terminology `structuring element` while going through reading materials. Now, let's discuss what this structuring element means.

# %% [markdown]
# ## Structuring Elements

# %% [markdown]
# As you know, the morphological operations take two inputs: one is the image object, and the other is a structuring element, which you combine using morphological operators to produce the output. Here, we will be discussing the second part of the input taken by the morphological operations, i.e., the Structuring element.
#
# <div align="center">
# <figure>
# <!-- <img src="https://drive.google.com/uc?id=1RkPFEoP4hDSzzfN5xVKG2aO4Xoyomdgz" > -->
# <img src="https://i.postimg.cc/44FPv7sJ/image.png"/>
# <figcaption>Figure 3. Structuring elements with various shapes
# </figcaption>
# </figure>
# </div>

# %% [markdown]
# Structuring elements are the small shape or template that morphological techniques use to probe the images. The above figure shows various structuring elements such as box, tile, circle, and cross with small red circle as an origin. More specifically, it is the matrix of pixels, each with a value of 0 or 1. The matrix dimensions determine the size of the structuring element, while the pattern of ones and zeros determines its shape. Here, in the example below,  you can see three $5\times5$ structuring elements with shapes like square-shape, diamond-shape, and cross-shaped. Among the structuring elements, one of its elements represents the origin of the structuring element - shown by red box, as shown in figure below. This origin can also be outside the structuring element.
#
# <div align="center">
# <figure>
# <!-- <img src="https://drive.google.com/uc?id=1ORUHWut-Z7T58eO47gqhL4aMHqWBuQTt" > -->
# <img src="https://i.postimg.cc/PqPY5KvY/image.png">
# <figcaption>Figure 4. Structuring element with matrix representation
# </figcaption>
# </figure>
# </div>

# %% [markdown]
# ### Hit-fit conditions

# %% [markdown]
# This is the basic rule for various morphological operations. It has two conditions, i.e., fit and hit.
#
# To satisfy fit condition, all pixels of structuring element must be same as image pixels on that particular region. Similarly, to satisfy hit condition, at least one pixel of structuring element should be activated by image pixels on that particular region. Let's understand what it means with following example.
#
# Suppose there are two structuring elements (cross-shaped and box shaped) and we have a image matrix having dimension of $9\times7$. Here we are considering particular scenario in these two green and blue regions where two structuring elements are operated. First, when cross-shaped structuring element is placed on this green region, it will satisfy the fit condition if both region have same pixels or all of its white pixels are activated by green region pixels. Then, fit condition will be satisfied and it's value will be 1.
# Similarly, for a hit condition, at least one of the pixels of this structuring element must be activated, it is also true for this condition so value will be again 1.
#
# <div align="center">
# <figure>
# <!-- <img src="https://drive.google.com/uc?id=1ihDvswl7FeYiO_4yowXs31nu0j1Zo-RX" height=350 width=650 > -->
# <img src="https://i.postimg.cc/43V4Phrj/image.png"/>
# <figcaption>Figure 4. Structuring element with matrix representation
# </figcaption>
# </figure>
# </div>
#
# Now, consider the second case where the second structuring element is placed over the blue region. You can see the last element of the first row of this structuring element matrix is not activated by the blue region or structuring element and blue region don't have identical pixels. Therefore, it won't satisfy the fit condition and it's value will be zero. However, for hits condition, at least one element of the structuring element matrix should be activated which is true for this condition and hence value for this condition will be one. This is how overall processing calculation is done for different morphological operations.

# %% [markdown]
# Structuring pixels are not only represented by 0's and 1's but also sometimes by '$\times$'(don't care pixels), as shown in the figure below.

# %% [markdown]
# <div align="center">
# <figure>
# <!-- <img src="https://drive.google.com/uc?id=1yG4F5dejyIjEeNfzRnb8eP4wA1r-caps" height=200 > -->
# <img src="https://i.postimg.cc/hjzSvZnF/image.png">
# <figcaption>Figure 3. Structuring elements with don't care element with the center being its origin represented by a dot
# </figcaption>
# </figure>
# </div>

# %% [markdown]
# **NOTE:**
#
# * In practice, odd dimension structuring matrix is preffered and origin is defined as the centre of matrix

# %% [markdown]
# ## Morphological Operations

# %% [markdown]
# Morphological operations are the processes that produces a processed/output image when you apply a  structuring element on an input image. Now, the question arises what type of morphological operations can you perform. The fundamental morphological operations are,
#
# - erosion operation
# - dilation operation
#
# And some other common operations blended by the above two erosion and dilation operations are,
#
# - opening operation
# - dilation operation
# - hit or miss operation
#
# We will discuss some of these operations in the following section.

# %% [markdown]
# ## Erosion

# %% [markdown]
# Erosion is a morphological operation where you erode the boundary area of foreground pixels(i.e., white or 1's pixels). Now, you know that erosion operation shrinks the areas of the foreground pixels, or you can say that holes within those areas become larger. Using erosion, you can eliminate the narrow regions and make thin the wider ones.

# %% [markdown]
# Let's see the mathematical definition of the erosion. For this, let us consider a set $A$ that contains the foreground pixels. If $ B $ is a structuring element, and if there is a pixel $z$, which translates $ B $ into another position such that $ B $ is in $ A $, then the set containing all such $z$ is the eroded representation of $A$. Mathematically we can represent this as:
#
# $$
#     A \ominus B = \{ z | (B)_z \subseteq A \}
# $$
#
#
# In the case of image $I$, there are foreground pixels and background pixels(0's or black pixels). Therefore inputs and outputs are images, and you can represent it as:
#
# $$
#     I \ominus B = \{ z|(B)_z \subseteq A\ and\ A \subseteq I\} \cup \{ A^c | A^c \subseteq I \}
# $$
# This means that what we perform erosion on foreground pixels and combine all the background pixels (pixels in $A^c$), results in a complete image.

# %% [markdown]
# **NOTE:**
#
# * Erosion removes the pixels on the boundaries
# * Structuring element is a matrix of 1's and 0's
# * Structuring element is a sub-image
# * For a grayscale image,
#
#   Erosion of a grayscale image of function $f$ with grayscale structuring element $b$ at the location (x,y) is the minimum value of the image in the region coincident with $b(x,y)$ when the origin of b is at $(x,y)$ (<a>Gonzalez, R. C., Woods, R. E., & Eddins, S. L., 2004, p.855</a>).
# $$
# (f\ominus b)(x,y) = \min_{(s,t)\in b}{f(x+s, y+t)}
# $$

# %% [markdown]
# ### Working Process

# %% [markdown]
# For clarification, let's see a simple example to explain it's working process.
#
# <div align="center">
# <figure>
# <!-- <img src="https://drive.google.com/uc?id=19m1eaEQEU3FaZ97NRwMEN08C57CYi7tr" height=350 width=700 > -->
# <img src="https://i.postimg.cc/XYMvTb9R/image.png" height=350 width=700/>
# <figcaption>Figure 4. Structuring element with matrix representation
# </figcaption>
# </figure>
# </div>

# %% [markdown]
# Here, the question arises on how you can do this calculation. The erosion operation performed above is straightforward. It follows the fit condition we discussed above. For gentle reminder, you will be able to complete the erosion operation like this,
#
# 1. You need to overlap each pixel of the image with the origin of the structuring element and slide it through each pixel.
# 2. You need to see if the overlapping of the structuring element perfectly matches or not with the area that you overlap it. If it perfectly matches, the pixel value becomes 1 else 0.

# %% [markdown]
# In the above example, no pixels of the image matrix overlaps perfectly with the 3x3 cross shaped structuring element matrix and that's why output image matrix contains all black pixels. Let's see this with another 5x5 structuring element.
#
# <div align="center">
# <figure>
# <!-- <img src="https://drive.google.com/uc?id=14QVHi_VD0jifN0Ud-ju5LpPuMh_xUDeY" height=350 width=700 > -->
# <img src="https://i.postimg.cc/ZYGZqL03/image.png"/>
# <figcaption>Figure 4. Structuring element with matrix representation
# </figcaption>
# </figure>
# </div>
#
# Here, you may wonder how only single white pixel in the output image. You can see when structuring element's origin placed on that position it perfectly fits with the image pixels and gives 1 value and for all other position there is no perfect fits for 5x5 cross-shaped structuring element. Now, let's look some of it's properties.

# %% [markdown]
# ### Properties

# %% [markdown]
# * Translation invariant
#
#   $$
#   (A + x)\ominus B = (A \ominus B) +x = A\ominus (B+x)
#   $$
#
#   Shifting in the image object or structuring element does not affect the erosion operation.
#
# * Erosion is increasing
#
#   $$If A \subseteq C, A\ominus B \subseteq C \ominus B$$
#   where $B$ is structuring element and $A$ and $C$ are image objects.
#
# *  Satisfy Decomposition theorem
# $$
#   A \ominus(B\cup C) = (A \ominus B)\cup(A\ominus C)
# $$
#
# * Erosion also statisfies following condition:
# $$(A \ominus B)\oplus C = A\ominus(B\oplus C)$$
# where $\oplus$ represent dilation

# %% [markdown]
# To summarize, erosion simply erodes away the boundary areas of the foreground pixels, which results in shrinking of image size.

# %% [markdown]
# ## Dilation

# %% [markdown]
# Dilation is just the opposite process of erosion operation. If erosion decreases the size of the image, dilation increases the image size. It only enlarges the boundary regions of the foreground pixels. One of its uses is to bridge the gap in a picture as it is an expansion operator that enlarges the image.

# %% [markdown]
# Like in erosion, let's define it mathematically. If $ A $ is the set representing foreground pixels, and $ B $ is the structuring elements, we can represent dilation of $ A $ by $ B $ $(A \oplus B)$ as
# $$
#     A \oplus B = \{z|(\hat{B})_z \cap A \ne \phi \}
# $$
#
# This means if you reflect the element about its origin, and translate this reflection by pixel z, the set of all z consists of pixels where foreground elements of structure $B$ overlap with at least one element of $A$.
#
# If you see the structuring element as some kernel, this process is similar to convolution, where you flip the kernel and slide through the image. In this case, we only take those pixels where this kernel and foreground pixels overlap.

# %% [markdown]
# **NOTE:**
#
# * For a grayscale image,
#
#   Dilation of a grayscale image $f$ with grayscale structuring element $b$ at any location (x,y) is the maximum value of the image in the window spanned by $\hat{b}$ when the origin of $\hat{b}$ is at (x,y)(<a>Gonzalez, R. C., Woods, R. E., & Eddins, S. L., 2004, p.855</a>).
# $$
# (f\oplus b)(x) = \max_{(s,t)\in \hat{b}}{f(x-s, y-s)},
# $$
# where, $\hat{b}(x,y) = b(-x, -y)$, i.e., structuring element b is reflected about its origin

# %% [markdown]
# ### Working Process

# %% [markdown]
# Similar to erosion, for explaining the working process of dilation in a binary image, we have an $f$ as image objects and $s$ as a structuring elements, respectively, as shown below and perform the dilation operation.
#
# Here, the calculation is same as erosion operation performed above. Only difference is it follows the hit condition we discussed earlier. For a gentle reminder, you will be able to complete the dilation operation like this,
#
# 1. You need to overlap each pixel of the image with the origin of the structuring element and slide it through each pixel.
# 2. You need to see if at least one pixel of the structuring element activated by the white pixels of the image object. If this happens, the pixel value where origin is located becomes 1 else 0.
#
# <div align="center">
# <figure>
# <!-- <img src="https://drive.google.com/uc?id=1IDAZ7syCv8_1j_LMyiQd2IsGCuB0Guef" height=350 width=700 > -->
# <img src="https://i.postimg.cc/Zq3LF44V/image.png"/>
# <figcaption>Figure 4. Structuring element with matrix representation
# </figcaption>
# </figure>
# </div>
#
# Let's see another example of dilating image object with $5\times5$ structuring element. Here, you can see most of the pixels are white in the output image because of the hit condition. Now, let's look some of it's properties.
#
# <div align="center">
# <figure>
# <img src="https://drive.google.com/uc?id=1m09Tth7Jdb_E2D9U8RvbvBog9F0ngbkX" height=350 width=700 >
# <img src="https://i.postimg.cc/pXR83KxQ/image.png" height=350 width=700/>
# <figcaption>Figure 4. Structuring element with matrix representation
# </figcaption>
# </figure>
# </div>

# %% [markdown]
# ### Properties

# %% [markdown]
# * Translation invariant
#
#   $$
#  (A \oplus B) +x = A\oplus (B+x)
#   $$
#
#   Shifting in the image object or structuring element does not affect the dilation operation.
#
# * Dilation is increasing
#
#   $$If A \subseteq C, A\oplus B \subseteq C \oplus B$$
#   where $B$ is structuring element and $A$ and $C$ are image objects.
#
# *  Satisfy Decomposition theorem
# $$
#   A \ominus(B\cup C) = (A \ominus B)\cup(A\ominus C)
# $$
#
# * Satisfy associative property
#
#  $$
#  (A \oplus B)\oplus C = A\oplus (B\oplus C)
#   $$
#
# * Satisfy commutative property
#  $$
#  A \oplus B  = B\oplus A
#   $$

# %% [markdown]
# **Duality**
#
# By using some complements and reflection, we can get the dual relationship between erosion and dilation.
#
# $$
#     (A \oplus B)^c = A^c \ominus \hat{B}
# $$
# $$
#     (A \ominus B) ^ c = A^c \oplus \hat{B}
# $$
# where $\hat{B}$ is the reflection of B.
#
# From the above equations, it is clear that you obtain the results similar to the diation of the $A$ by performing the erosion on background pixels of $A$(i.e $A^{c}$) and taking its complement and vice-versa. Here, the structuring element on both cases are $B$, and $\hat{B}$. If the structuring element is symmetric, in the above equations, $B = \hat{B}$.

# %% [markdown]
# To summarize, dilation is simply the opposite of erosion. Here, you find that boundary areas of the foreground pixels gradually enlarges.

# %% [markdown]
# ## Opening

# %% [markdown]
# An opening is the compounded morphological operation derived from the fundamental operations erosion and dilation. Opening somewhat behaves like erosion but less destructive. Here, you remove some foreground pixels from the boundary region of the image. An opening is a process in which erosion operation follows the dilation. You can see this clearly in its mathematical definition presented below.

# %% [markdown]
# For any set of foreground elements, $ A $ and structuring element $ B $ opening of A by B is
#
# $$
#     A \circ B = (A \ominus B) \oplus B
# $$
# This means the opening is erosion, followed by dilation using the same structuring elements.
#
# As we know that erosion removes some after of the elements from the foreground, and following the dilation, we refill these parts.
#
# Using the opening, we can smooth surfaces, break narrow ridges, and eliminate protrusions. If you take a square structuring element of 5x5 pixels, you can remove all artifacts with less than 5.

# %% [markdown]
# <div align="center">
# <figure>
# <!-- <img src="https://drive.google.com/uc?id=19uF-EGnni5MHFbZZ_1fG12JtlMvIGW7s" height=200 width=700 > -->
# <img src="https://i.postimg.cc/3wyXr7k3/image.png" height= 200 width =700>
# <figcaption>Figure 4. Structuring element with matrix representation
# </figcaption>
# </figure>
# </div>
#
# From the above figure, you can see the differences between erosion and opening. Erosion operation has eroded a lot of the character while Opening operation has thicked the character. The reason for it is that the main task of erosion operation is to erode the image object while opening does two actions: one is erosion, and the other is dilation. Here, the dilation process is overtaking the erosion action and making the character thicker.

# %% [markdown]
# **Properties:**
#
# * Idempotent
#
#   $$(A\circ B) \circ B = A\circ B$$
#
# * Increasing monotonicity
#
#   If $A\subseteq C$, $A\circ B \subseteq C\circ B$, where A and C are image objects, and B is  structuring element
#
# *  Translation Invariant
#
#   $$ (A +x)\circ B = (A\circ B)+x$$

# %% [markdown]
# # Closing

# %% [markdown]
# Closing is the dual of the opening process. It is the composite operation derived from fundamental operations erosion and dilation. It is similar to dilation in some manner as it tends to increase the boundary of the foreground regions in an image. It is the reverse process of opening. As the opening is erosion followed by dilation, it is dilation followed by erosion, as shown in the mathematical definition below.

# %% [markdown]
# For any set of foreground elements, $A$ and structuring element $B$ closing of A by B is,
#
# $$
#     A \bullet B = (A \oplus B) \ominus B
# $$
# This means closing is dilation, followed by erosion using the same structuring elements.
#
# Unlike opening that removes all the structure where the structuring elements don't fit, closing fills all the background elements where structure elements don't fit. Therefore it can be used as fusions for small breaks, thing gulfs, and small holes.

# %% [markdown]
# <div align="center">
# <figure>
# <!-- <img src="https://drive.google.com/uc?id=17w87SGmVIjY91Wx5nP22dmRMqyUnXSHA" height=200 width=700 > -->
# <img src="https://i.postimg.cc/26VKfPDW/image.png">
# <figcaption>Figure 4. Structuring element with matrix representation
# </figcaption>
# </figure>
# </div>
#
# From the above figure, you can see the differences between the dilation and closing operations. The dilation operations made the character thicker than the closing operation. It is so because the main task of dilation is to add foreground pixels to the image while closing operation performs two tasks: one is dilation and erosion, and the erosion task erodes the character enlarged by the dilation task.

# %% [markdown]
# **Properties:**
#
# * Idempotent
#
#   $$(A\bullet B) \bullet B = A\bullet B$$
#
# * Increasing monotonicity
#
#   If $A\subseteq C$, $A\bullet B \subseteq C\bullet B$, where A and C are image objects, and B is  structuring element
#
# *  Translation Invariant
#
#   $$ (A +x)\bullet B = (A\bullet B)+x$$

# %% [markdown]
# Besides these, there is also [hit and miss transform](https://homepages.inf.ed.ac.uk/rbf/HIPR2/hitmiss.htm) morphological operation, which you can use to look at particular patterns of foreground and background pixels in an image. For the detailed explanation of this method, you can follow the above link as we are not discussing it in later chapters. There are other morphological operations like [thinning](https://homepages.inf.ed.ac.uk/rbf/HIPR2/thin.htm), [thickening](https://homepages.inf.ed.ac.uk/rbf/HIPR2/thick.htm), [skeletonization/medial axis transform](https://homepages.inf.ed.ac.uk/rbf/HIPR2/skeleton.htm).

# %% [markdown]
# ## Applications
# You can see many applications in the above examples. To mention, these are some practical applications of the morphological image processing.
#
# - Boundary extraction
#
# - Region filing
#
# - Extraction of connected components
#
# - Convex hull
#
# - Thickening
#
# - Thinning
#
# - Pruning

# %% [markdown]
# # Key Takeaways

# %% [markdown]
# - Morphological image processing are various non-linear operations that deals with shapes of an image object.
#
# - Morphological operators come from set-theory concepts.
#
# - Structuring elements are the sub-image used for performing morphological operations.
#
# - Some common morphological operations are erosion, dilation, opeing, and closing.
#
# - The opening can be used to smoothen, break narrow ridges and eliminate protrusions
#
# - Closing can be used to fuse narrow breaks, thin gulfs, and small holes

# %% [markdown]
# # References
#
# - Gonzalez, R. C., Woods, R. E., & Eddins, S. L. (2004). Digital image processing using MATLAB. Pearson Education India.
